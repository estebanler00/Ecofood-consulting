# %%
"""
https://scrapbot.link/
PREPARATIVOS DEL BOT SCRAPPER

links de posible uso:
Scielo: bibliografia completa de multiples fuentes
https://www.scielo.org.ar/scielo.php?script=sci_arttext&pid=S1852-73372022000100090

Segunda encuensta 2021 de nutricion y salud.
https://datos.salud.gob.ar/dataset/ennys2/archivo/5ef1b908-a038-4785-9f5d-eb5036c6adce

Los 10 mejores restaurantes de buenos aires
https://www.tripadvisor.com.ar/Restaurants-g312741-c10679-Buenos_Aires_Capital_Federal_District.html

PedidosYa restaurantes Comidas saludables Buenos aires
https://www.pedidosya.com.ar/restaurantes?address=Buenos%20Aires&areaId=18773&lat=-34.6036844&lng=-58.3815591&query=saludable

guia oleo
https://www.guiaoleo.com/buenos-aires/restaurants
"""
# Out:
# hola mundo

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


base_url = "https://www.guiaoleo.com/buenos-aires/restaurants?page={}"
datos = []
page = 1
max_pages = 5  # Limitar a 10 páginas para evitar sobrecarga
while page <= max_pages:
    response = requests.get(base_url.format(page))
    soup = BeautifulSoup(response.text, "html.parser")

    resto_nombre = soup.find_all("div", class_="flex items-start mb-1") 
    resto_ficha = soup.find_all("div", class_="flex items-center flex-wrap gap-x-2 gap-y-1 text-sm text-gray-600 dark:text-gray-400")
    # si ya no hay más restaurantes, corto el bucle
    if not resto_nombre:
        break

    for i in range(len(resto_nombre)):
        nombre = resto_nombre[i].find("span").get_text(strip=True)
        spans = resto_ficha[i].find_all("span")
        if len(spans) >= 5:
            localizacion = spans[0].get_text(strip=True)
            tipo = spans[2].get_text(strip=True)
            precio = spans[4].get_text(strip=True)
            datos.append([nombre, localizacion, tipo, precio])

    print(f"Página {page} procesada, total acumulado: {len(datos)}")
    page += 1

# convertir a DataFrame
df = pd.DataFrame(datos, columns=["Nombre", "Localización", "Tipo", "Precio"])
print(df)
# Out:
# Página 1 procesada, total acumulado: 6
# Página 2 procesada, total acumulado: 12
# Página 3 procesada, total acumulado: 18
# Página 4 procesada, total acumulado: 24
# Página 5 procesada, total acumulado: 30
#                  Nombre  Localización          Tipo Precio
# 0   Naty Blacher Cocina  Buenos Aires    Pastelería    $$$
# 1            Mishiguene  Buenos Aires  Mediterránea   $$$$
# 2                Bácaro  Buenos Aires           Bar     $$
# 3              DOC Café  Buenos Aires          Café     $$
# 4   NANI Cocina Armenia  Buenos Aires  Mediterránea     $$
# 5          Gran Dabbang  Buenos Aires         India     $$
# 6   Naty Blacher Cocina  Buenos Aires    Pastelería    $$$
# 7            Mishiguene  Buenos Aires  Mediterránea   $$$$
# 8                Bácaro  Buenos Aires           Bar     $$
# 9              DOC Café  Buenos Aires          Café     $$
# 10  NANI Cocina Armenia  Buenos Aires  Mediterránea     $$
# 11         Gran Dabbang  Buenos Aires         India     $$
# 12  Naty Blacher Cocina  Buenos Aires    Pastelería    $$$
# 13           Mishiguene  Buenos Aires  Mediterránea   $$$$
# 14               Bácaro  Buenos Aires           Bar     $$
# 15             DOC Café  Buenos Aires          Café     $$
# 16  NANI Cocina Armenia  Buenos Aires  Mediterránea     $$
# 17         Gran Dabbang  Buenos Aires         India     $$
# 18  Naty Blacher Cocina  Buenos Aires    Pastelería    $$$
# 19           Mishiguene  Buenos Aires  Mediterránea   $$$$
# 20               Bácaro  Buenos Aires           Bar     $$
# 21             DOC Café  Buenos Aires          Café     $$
# 22  NANI Cocina Armenia  Buenos Aires  Mediterránea     $$
# 23         Gran Dabbang  Buenos Aires         India     $$
# 24  Naty Blacher Cocina  Buenos Aires    Pastelería    $$$
# 25           Mishiguene  Buenos Aires  Mediterránea   $$$$
# 26               Bácaro  Buenos Aires           Bar     $$
# 27             DOC Café  Buenos Aires          Café     $$
# 28  NANI Cocina Armenia  Buenos Aires  Mediterránea     $$
# 29         Gran Dabbang  Buenos Aires         India     $$
