# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import pandas as pd

ruta_archivo = r"c:\Users\comun\OneDrive\Escritorio\Consulting_EcoFood\Oferta_gastronomica\oferta_gastronomica.csv"

# Cambiamos 'sep' a punto y coma
df = pd.read_csv(ruta_archivo, sep=';', encoding='latin-1', on_bad_lines='skip')

# %%
df.head(5)
# Out:
#            long           lat    id           nombre    categoria  \
# 0  -58,36330675  -34,62296347  1602     GUANTANAMERA  RESTAURANTE
# 1  -58,39232963  -34,62155353   676  1843 VINACOTECA      VINERIA
# 2  -58,45354227  -34,56031135   487     2080 EXPRESS  RESTAURANTE
# 3  -58,47549105   -34,6770507  2737               22         CAFE
# 4   -58,4254372  -34,58569501     2         4 EN 2 I  RESTAURANTE
#
#         cocina       ambientacion   telefono mail                    horario  \
# 0       CUBANA            MODERNO  4314 0770  NaN                        NaN
# 1          NaN                NaN  4779 0806  NaN  lunes a domingo de 8 a 00
# 2  TRADICIONAL  CLASICO PORTEï¿½O  4788 4500  NaN  lunes a domingo de 8 a 00
# 3      MINUTAS            MODERNO        NaN  NaN                        NaN
# 4          NaN                NaN  4832 9510  NaN                        NaN
#
#              calle_nombre  calle_altura calle_cruce  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   long                     2823 non-null   str
#  1   lat                      2823 non-null   str
#  2   id                       2823 non-null   int64
#  3   nombre                   2823 non-null   str
#  4   categoria                2707 non-null   str
#  5   cocina                   2464 non-null   str
#  6   ambientacion             2264 non-null   str
#  7   telefono                 2303 non-null   str
#  8   mail                     472 non-null    str
#  9   horario                  725 non-null    str
#  10  calle_nombre             2823 non-null   str
#  11  calle_altura             2823 non-null   int64
#  12  calle_cruce              6 non-null      str
#  13  direccion_completa       2822 non-null   str
#  14  barrio                   2823 non-null   str
# ...

# %%
print(df.dtypes)
# Out:
# long                           str
# lat                            str
# id                           int64
# nombre                         str
# categoria                      str
# cocina                         str
# ambientacion                   str
# telefono                       str
# mail                           str
# horario                        str
# calle_nombre                   str
# calle_altura                 int64
# calle_cruce                    str
# direccion_completa             str
# barrio                         str
# comuna                       int64
# codigo_postal              float64
# codigo_postal_argentino        str
# dtype: object

# %%
conteo = df['categoria'].value_counts()

print(conteo)
# Out:
# categoria
# RESTAURANTE             1990
# CAFE                     334
# BAR                      247
# CONFITERIA                55
# PUB                       53
# VINERIA                   22
# SANDWICHERIA               4
# DELIVERY & TAKE AWAY       2
# Name: count, dtype: int64

# %%
tipo_cocina = df['cocina'].value_counts()

print(tipo_cocina)



df.info(['cocina'])
# Out:
# cocina
# MINUTAS             737
# INTERNACIONAL       448
# TRADICIONAL         297
# PIZZERIA            176
# PARRILLA            159
# SANDWICHERIA        127
# FAST FOOD            81
# ITALIANA             77
# MEDITERRANEA         48
# PORTEÃA             39
# DE AUTOR             32
# REGIONAL             30
# ESPAÃOLA            25
# CHINA                17
# SUSHI                12
# TENEDOR LIBRE        11
# JAPONESA             10
# AMERICANA             9
# FUSION                8
# FRANCESA              8
# TAPAS                 8
# NATURISTA             7
# MEXICANA              7
# MARISCOS              7
# MODERNO               7
# CUBANA                6
# ARABE                 6
# ARMENIA               6
# BOLIVIANA             6
# GOURMET               5
# CLASICO PORTEÃO      4
# ORIENTAL              4
# VEGETARIANA           4
# PERUANA               4
# ALEMANA               3
# PATAGONICA            3
# JUDIA                 3
# TAILANDESA            3
# ...
